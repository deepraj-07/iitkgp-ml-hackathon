# %% [markdown]
# <a href="https://colab.research.google.com/github/deepraj-07/iitkgp-ml-hackathon/blob/main/PravahAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# PravahAI
## IIT Kharagpur ML Hackathon

### Team Members
- Deep Raj
- Kripashankar Yadav
- Shikha Agnihotri
- Unnisha Sen

### Objective
Predict the yield (%) of Product B in a continuous chemical reactor.

# %%
# 1. Import Libraries

# %%
# 2. Load Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from pathlib import Path

DATA_PATH = Path("/content/drive/MyDrive/PravahAI")

train_df = pd.read_csv(DATA_PATH / "train_dataset.csv")
test_df = pd.read_csv(DATA_PATH / "test_dataset.csv")

print("Train Shape:", train_df.shape)
print("Test Shape :", test_df.shape)
# Out:
# Train Shape: (150, 6)
# Test Shape : (50, 5)

# %%
# 3. Data preprocessing
- Missing Values
- Data Types
- Duplicate Rows
- Basic Cleaning

# %%
# 4. Exploratory Data Analysis (EDA)
- Distribution
- Correlation
- Outliers
- Target Analysis

# %%
# 5. Physics Based Feature Engineering
- Residence Time
- Temperature Difference
- Heat Exposure
- Flow × Concentration
- Polynomial Features
- Interaction Features

# %%
# 6. Model Training
- Random Forest (Baseline)
- CatBoost
- LightGBM
- XGBoost
- Extra Trees

# %%
# 7. Hyperparameter Tuning (Optuna)

# %%
# 8. K-Fold Cross Validation

# %%
# 9. Ensemble Learning

# %%
# 10. SHAP Explainability

# %%
# 11. Predict Test Dataset

# %%
# 12. Generate Submission CSV
